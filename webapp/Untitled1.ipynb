# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from StravaUser import StravaUser
from StravaModel import StravaModel
from StravaEffort import StravaActivity
from sklearn.ensemble import GradientBoostingRegressor, RandomForestRegressor, AdaBoostRegressor
from sklearn.svm import SVR
from sklearn.linear_model import LinearRegression, BayesianRidge, RANSACRegressor
from sklearn.cross_validation import cross_val_score, train_test_split
from sklearn.preprocessing import StandardScaler, PolynomialFeatures
from sklearn.metrics import r2_score
from SignalProc import smooth
import pickle
# %matplotlib inline
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-2-b54ca17e350e> in <module>()
#       2 import numpy as np
#       3 import matplotlib.pyplot as plt
# ----> 4 from StravaUser import StravaUser
#       5 from StravaModel import StravaModel
#       6 from StravaEffort import StravaActivity
#
# /Users/datascientist/seth/CycleAnalysis/webapp/StravaUser.py in <module>()
#       6 from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
#       7 from datetime import datetime, timedelta
# ----> 8 from StravaEffort import StravaActivity
#       9 from StravaDB import StravaDB
#      10 from StravaAPI import StravaAPI
#
# /Users/datascientist/seth/CycleAnalysis/webapp/StravaEffort.py in <module>()
#       5 from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
#       6 import matplotlib.pyplot as plt
# ----> 7 from StravaDB import StravaDB
#       8 from datetime import datetime, timedelta, date
#       9 import pymongo
#
# /Users/datascientist/seth/CycleAnalysis/webapp/StravaDB.py in <module>()
# ----> 1 import MySQLdb as sql
#       2 import pymongo
#       3 import traceback
#       4 from datetime import datetime, date, timedelta
#       5 import numpy as np
#
# ImportError: No module named MySQLdb

# %%
ryan = StravaUser(6789642, get_streams=True, get_routes=False)

# %%
user = ryan
delete = [8, 12, 22, 24, 31, 37, 2, 33]
# delete = []
indices = np.arange(len(user.activities))
indices = np.delete(indices, delete)
train_indices = np.random.choice(indices, size=int((len(user.activities) - len(delete))*0.7), replace=False)
test_indices = np.setdiff1d(indices, train_indices)

df = user.make_df(train_indices)
y = df['velocity'].values
cols = df.columns
X = df[cols[np.where(cols!='velocity')]].values
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3)

# %%
# poly = PolynomialFeatures(degree=2)
# X = poly.fit_transform(X)
# model = RANSACRegressor(LinearRegression())
# model = LinearRegression()
model = GradientBoostingRegressor(n_estimators=200)
# model = RandomForestRegressor(max_depth=20, min_samples_split=50)

# %%
model.fit(X, y)
# Out:
# RandomForestRegressor(bootstrap=True, compute_importances=None,
#            criterion='mse', max_depth=20, max_features='auto',
#            max_leaf_nodes=None, min_density=None, min_samples_leaf=1,
#            min_samples_split=50, n_estimators=10, n_jobs=1,
#            oob_score=False, random_state=None, verbose=0)

# %%
df_test = user.make_df(test_indices)
y = df_test['velocity'].values
cols = df_test.columns
X = df_test[cols[np.where(cols!='velocity')]].values
print r2_score(y, model.predict(X))
df_train = user.make_df(train_indices)
y = df_train['velocity'].values
cols = df_train.columns
X = df_train[cols[np.where(cols!='velocity')]].values
print r2_score(y, model.predict(X))
# Out:
# 0.421741533353
# 0.96413674648

# %%
errors = []
errors2 = []
outliers = []
for idx, a in enumerate(user.activities):
    df = a.make_df()
    y = df.pop('velocity')
    X = df.values
#     X = poly.transform(X)
    pred = model.predict(X).ravel()

    
#     a.predict(model)
    error = (pred[-1] - a.moving_time)/a.moving_time
    error2 = np.mean(pred - y)
    errors2.append(error2)
#     errors.append(error)
    r2 = r2_score(y, pred)
    diff = np.mean(y - pred)

    r2_offset = r2_score(y, pred-diff)
    if error2 > 0.5:
# 28 0.960121744512 0.959510674588 -0.000611069924777 Double Ups on Red and Wilson 0.0359188319877
# 29 0.921658939 0.904109218495 -0.0175497205054 Ridin 0.129491893795
# 30 0.941078839112 0.925862237244 -0.0152166018682 Wilson Hill at lunch -0.201375976889
# 31
#  -0.0302040761472 -0.892280747752 -0.862076671605 Marin Rollin 1.05665213829
# 32 -6.8347278247 -26.7125084132 -19.8777805885 Trainin' with Hannah 2.25574087544
# 33 -11.0465367987 -37.3748772583 -26.3283404596 Ride round 2: John's back in CA 2.967003584
# 34 0.964201503231 0.955631059012 -0.00857044421856 Search and Destroy -0.134632421028
# 35 0.881379617328 0.755166911553 -0.126212705775 Reverse sling shot: when the Moons propels around you -0.410313868362
# 36
#  0.8802110367 0.865192297596 -0.0150187391035 Saddle time 0.0787077765239
# 37 -6.76941741593 -26.9450612784 -20.1756438625 Healdsburg to Cloverdale w/ H 2.52836094774
# 38 -5.50016196509 -17.3249338144 -11.8247718493 Catapult into the mud 2.3389687868
# 39 0.915528514476 0.872644066207 -0.0428844482688 One-way ticket: SR to Petaluma -0.13198891484
# 40 -8.12188485758 -22.6876557525 -14.5657708949 Mnt Bike 2.36187293207
# 41
#  0.862385616426 0.847298216612 -0.0150873998146 Trash can sprint -0.073872203335
# 42 0.929872804418 0.928982730425 -0.000890073992993 Bici Sunday 0.0327316270587
# 43 0.986784245302 0.985913967223 -0.000870278078905 Up hill lunch -0.0567741567865
# 44 0.894851580326 0.786689663087 -0.108161917238 Awful Weather spin... 0.444641771734
# 45
#  0.970405086126 0.970404962954 -1.23171480904e-07 No wind, no clouds, no worries 0.000516081288089
# [0, 1, 2, 8, 12, 17, 22, 24, 31, 32, 33, 37, 38, 40]
# [ 0  1  5  7 17 19 26 27 32 38 40 44]

# %%
a = user.activities[12]
df = a.make_df()
y = df.pop('velocity')
X = df.values
# X = poly.transform(X)
pred = model.predict(X).ravel()
fig, axs = plt.subplots(2, 1, figsize=(15, 12))
ax = axs[0]
ax.plot(a.df.distance, smooth(a.df.grade, 'scipy', 20), c='r')
ax = ax.twinx()
ax.grid(b=False)
ax.plot(a.df.distance, a.df.altitude)
# ax.plot(a.df.distance, smooth(a.df.grade, 'scipy', 10000), c='b')
ax = axs[1]
# ax.grid(b=False)
ax.plot(a.df.distance, y)

offset = np.mean(pred - y)
offset=0
ax.plot(a.df.distance, pred-offset, label='predicted')
ax.legend()
g = np.diff(a.df.altitude) * 100 / np.diff(a.df.distance)
g = np.append(g, 0)
# ax.plot(a.df.distance, smooth(g, 'scipy', 50))
# ax.plot(a.df.distance, smooth(a.df.grade, 'scipy', 50))
plt.suptitle(r2_score(y, pred-offset))
